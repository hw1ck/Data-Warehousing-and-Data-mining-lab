# %% [markdown]
# <a href="https://colab.research.google.com/github/hw1ck/Data-Warehousing-and-Data-mining-lab/blob/main/DWDM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e5e4559-ba2d-4823-bc97-cec294d3d2f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e5e4559-ba2d-4823-bc97-cec294d3d2f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df =  pd.read_csv('employee1.csv')
df.head()
# Out:
#    employee_id             name  age    department  salary  purchases
# 0          501      Kobe Bryant   20   Engineering   81000    10000.0
# 1          502    Kendric Lamar   19      Medicine   78000    10000.0
# 2          503   Kiliyan Mbappe   19   Engineering   80000     7000.0
# 3          504         Dua Lipa   20      Medicine   87000    20000.0
# 4          505   Pedri Gonzalez   20           Law   90000        NaN

# %%
with open('employee1.csv', mode='r')as file:
  csvFile = csv.reader(file)
  for lines in csvFile:
    print(lines)
# Out:
# ['employee_id', 'name', 'age', 'department', 'salary', 'purchases']
# ['501', ' Kobe Bryant', ' 20', ' Engineering', ' 81000', ' 10000']
# ['502', ' Kendric Lamar', ' 19', ' Medicine', ' 78000', ' 10000']
# ['503', ' Kiliyan Mbappe', ' 19', ' Engineering', ' 80000', ' 7000']
# ['504', ' Dua Lipa', ' 20', ' Medicine', ' 87000', ' 20000']
# ['505', ' Pedri Gonzalez', ' 20', ' Law', ' 90000']
# ['506', ' Hardik Pandya', ' 20', ' Medicine', ' 76000', ' 10000']
# ['507', ' Tyla', ' 19', ' Law', ' 85000']
# ['508', ' Maddison Beer', ' 21', ' Engineering', '72000', '21000']
# ['509', ' Jude Bellingham', ' 19', ' Medicine', ' 89000', '15000']
# ['510', ' Billie Eilish', ' 20', ' Law', ' 87000']

# %%
df['purchases'] = df['purchases'].fillna(df['purchases'].median())
print(df)
# Out:
#    employee_id              name  age    department  salary  purchases
# 0          501       Kobe Bryant   20   Engineering   81000    10000.0
# 1          502     Kendric Lamar   19      Medicine   78000    10000.0
# 2          503    Kiliyan Mbappe   19   Engineering   80000     7000.0
# 3          504          Dua Lipa   20      Medicine   87000    20000.0
# 4          505    Pedri Gonzalez   20           Law   90000    10000.0
# 5          506     Hardik Pandya   20      Medicine   76000    10000.0
# 6          507              Tyla   19           Law   85000    10000.0
# 7          508     Maddison Beer   21   Engineering   72000    21000.0
# 8          509   Jude Bellingham   19      Medicine   89000    15000.0
# 9          510     Billie Eilish   20           Law   87000    10000.0

# %%
df['purchases'] = df['purchases'].fillna(df['purchases'].mean())
print(df)
# Out:
#    employee_id              name  age    department  salary     purchases
# 0          501       Kobe Bryant   20   Engineering   81000  10000.000000
# 1          502     Kendric Lamar   19      Medicine   78000  10000.000000
# 2          503    Kiliyan Mbappe   19   Engineering   80000   7000.000000
# 3          504          Dua Lipa   20      Medicine   87000  20000.000000
# 4          505    Pedri Gonzalez   20           Law   90000  13285.714286
# 5          506     Hardik Pandya   20      Medicine   76000  10000.000000
# 6          507              Tyla   19           Law   85000  13285.714286
# 7          508     Maddison Beer   21   Engineering   72000  21000.000000
# 8          509   Jude Bellingham   19      Medicine   89000  15000.000000
# 9          510     Billie Eilish   20           Law   87000  13285.714286

# %%
mode_value = df['purchases'].mode()[0]
df['purchases'] = df['purchases'].fillna(mode_value)
print(df)
# Out:
#    employee_id              name  age    department  salary  purchases
# 0          501       Kobe Bryant   20   Engineering   81000    10000.0
# 1          502     Kendric Lamar   19      Medicine   78000    10000.0
# 2          503    Kiliyan Mbappe   19   Engineering   80000     7000.0
# 3          504          Dua Lipa   20      Medicine   87000    20000.0
# 4          505    Pedri Gonzalez   20           Law   90000    10000.0
# 5          506     Hardik Pandya   20      Medicine   76000    10000.0
# 6          507              Tyla   19           Law   85000    10000.0
# 7          508     Maddison Beer   21   Engineering   72000    21000.0
# 8          509   Jude Bellingham   19      Medicine   89000    15000.0
# 9          510     Billie Eilish   20           Law   87000    10000.0
